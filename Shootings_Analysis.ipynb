# %%
import os

# %%
os.listdir('.lewis.data')
# Out:
# ['1976-2020-president.csv',
#  '1976-2020-senate.csv',
#  'country_wise_latest.csv',
#  'covid_19_clean_complete.csv',
#  'day_wise.csv',
#  'full_grouped.csv',
#  'shootings.csv',
#  'usa_county_wise.csv',
#  "WhatsApp Chat with BPC project Phany'20.txt",
#  'worldometer_data.csv']

# %%
import pandas as pd

# %%
Shootings_df = pd.read_csv("./.lewis.data/shootings.csv")

# %%
Shootings_df
# Out:
#         id                name        date   manner_of_death       armed  \
# 0        3          Tim Elliot  2015-01-02              shot         gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot         gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot  toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot    nail gun
# ...    ...                 ...         ...               ...         ...
# 4890  5916     Rayshard Brooks  2020-06-12              shot       Taser
# 4891  5925      Caine Van Pelt  2020-06-12              shot         gun
# 4892  5918        Hannah Fizer  2020-06-13              shot     unarmed
# 4893  5921      William Slyter  2020-06-13              shot         gun
# 4894  5924      Nicholas Hirsh  2020-06-15              shot         gun
#
#        age gender      race           city state  signs_of_mental_illness  \
# ...

# %%
Shootings_df.manner_of_death.unique()
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %%
Shootings_df['date'] = pd.to_datetime(Shootings_df.date)

# %%
Shootings_df.date
# Out:
# 0      2015-01-02
# 1      2015-01-02
# 2      2015-01-03
# 3      2015-01-04
# 4      2015-01-04
#           ...
# 4890   2020-06-12
# 4891   2020-06-12
# 4892   2020-06-13
# 4893   2020-06-13
# 4894   2020-06-15
# Name: date, Length: 4895, dtype: datetime64[ns]

# %%
Shootings_df['year'] = pd.DatetimeIndex(Shootings_df.date).year
Shootings_df['month'] = pd.DatetimeIndex(Shootings_df.date).month
Shootings_df['day'] = pd.DatetimeIndex(Shootings_df.date).day
Shootings_df['weekday'] = pd.DatetimeIndex(Shootings_df.date).weekday

# %%
Shootings_df.set_index( 'index', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-299e508a2efd> in <module>
# ----> 1 Shootings_df.set_index( 'index', inplace = True)
#
# c:\users\jonathan_k\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4725
#    4726         if missing:
# -> 4727             raise KeyError(f"None of {missing} are in the columns")
#    4728
#    4729         if inplace:
#
# KeyError: "None of ['index'] are in the columns"

# %%
Shootings_df
# Out:
#         id                name        date   manner_of_death       armed  \
# 0        3          Tim Elliot  2015-01-02              shot         gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot         gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot  toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot    nail gun
# ...    ...                 ...         ...               ...         ...
# 4890  5916     Rayshard Brooks  2020-06-12              shot       Taser
# 4891  5925      Caine Van Pelt  2020-06-12              shot         gun
# 4892  5918        Hannah Fizer  2020-06-13              shot     unarmed
# 4893  5921      William Slyter  2020-06-13              shot         gun
# 4894  5924      Nicholas Hirsh  2020-06-15              shot         gun
#
#        age gender      race           city state  signs_of_mental_illness  \
# ...

# %%
Shootings_df.describe()
# Out:
#                 id          age         year        month          day  \
# count  4895.000000  4895.000000  4895.000000  4895.000000  4895.000000
# mean   2902.148519    36.549750  2017.182227     6.058631    15.452911
# std    1683.467910    12.694348     1.584525     3.461983     8.786587
# min       3.000000     6.000000  2015.000000     1.000000     1.000000
# 25%    1441.500000    27.000000  2016.000000     3.000000     8.000000
# 50%    2847.000000    35.000000  2017.000000     6.000000    15.000000
# 75%    4352.500000    45.000000  2019.000000     9.000000    23.000000
# max    5925.000000    91.000000  2020.000000    12.000000    31.000000
#
#            weekday
# count  4895.000000
# mean      2.949745
# std       1.973757
# min       0.000000
# 25%       1.000000
# 50%       3.000000
# 75%       5.000000
# max       6.000000

# %%
Shootings_df.manner_of_death.unique()
# Out:
# array(['shot', 'shot and Tasered'], dtype=object)

# %% [markdown]
# # Who are the most killed race?

# %%
Shootings_df.race.value_counts() # This is the order of the most killed race to the least
# Out:
# White       2476
# Black       1298
# Hispanic     902
# Asian         93
# Native        78
# Other         48
# Name: race, dtype: int64

# %% [markdown]
# # On males and females,Who are killed the most?

# %%
Shootings_df.gender.value_counts() # As showed below..Males are killed morethan females
# Out:
# M    4673
# F     222
# Name: gender, dtype: int64

# %% [markdown]
# # In which city does the most number of shootings occur?

# %%
Shootings_df.city.value_counts() # According to the analysis, The most count of shots occurs in Los Angeles.
# Out:
# Los Angeles        78
# Phoenix            66
# Houston            51
# Las Vegas          41
# San Antonio        40
#                    ..
# Amity               1
# Baldwin County      1
# Canton Township     1
# Katy                1
# Fulshear            1
# Name: city, Length: 2288, dtype: int64

# %% [markdown]
# # Is the most number of people armed or not?.If Yes then Which is the most used Weapon?

# %%
Shootings_df.armed.value_counts() # According to my survey, Guns and knifes are the most used weapons.
# Out:
# gun               2755
# knife              708
# unknown            418
# unarmed            348
# toy weapon         171
#                   ...
# metal rake           1
# motorcycle           1
# cordless drill       1
# flagpole             1
# oar                  1
# Name: armed, Length: 89, dtype: int64

# %% [markdown]
# # For those who try escaping, What means do they use the most?

# %%
Shootings_df.flee.value_counts() # Most of use Cars and Foot but the largest number doesn't flee.
# Out:
# Not fleeing    3073
# Car             820
# Foot            642
# Other           360
# Name: flee, dtype: int64

# %% [markdown]
# # What is the most used manner of killing the suspects?

# %%
Shootings_df.manner_of_death.value_counts() # The most used manner of killing is by shooting followed by shooting and Tasered.
# Out:
# shot                4647
# shot and Tasered     248
# Name: manner_of_death, dtype: int64

# %% [markdown]
# # What is the threat level used?

# %%
Shootings_df.threat_level.value_counts()
# Out:
# attack          3160
# other           1528
# undetermined     207
# Name: threat_level, dtype: int64

# %%
Shootings_df.sample(5)
# Out:
#         id                  name       date   manner_of_death    armed   age  \
# 745    906       Anthony Aguilar 2015-10-10  shot and Tasered  unknown  35.0
# 1644  1899          Charles Dove 2016-09-20              shot      gun  35.0
# 3388  3966         Chris Cameron 2018-08-13              shot      gun  31.0
# 761    922       Herbert Benitez 2015-10-15              shot      gun  27.0
# 2876  3374  Alexander W. Simpson 2018-02-01              shot      gun  32.0
#
#      gender      race            city state  signs_of_mental_illness  \
# 745       M  Hispanic           Lisle    IL                    False
# 1644      M     White  Decatur County    TN                    False
# 3388      M     White         Creston    IA                     True
# 761       M  Hispanic   San Francisco    CA                    False
# 2876      M     White      Louisville    KY                    False
#
#       threat_level         flee  body_camera arms_category  year  month  day  \
# ...

# %% [markdown]
# # How many people killed have any signs of mental illness?

# %%
Shootings_df.signs_of_mental_illness.value_counts() # 1103 is the number of people killed with a mental illness.
# Out:
# False    3792
# True     1103
# Name: signs_of_mental_illness, dtype: int64

# %% [markdown]
# # What is the state with the highest deaths?

# %%
Shootings_df.state.value_counts() # CA is proved to the state with the highest deaths..
# Out:
# CA    701
# TX    426
# FL    324
# AZ    222
# CO    168
# GA    161
# OK    151
# NC    148
# OH    146
# WA    126
# TN    125
# MO    124
# LA    102
# IL     99
# PA     95
# AL     95
# NM     93
# VA     92
# IN     91
# NY     90
# WI     88
# KY     87
# NV     85
# SC     80
# MD     77
# OR     76
# AR     73
# MI     71
# MS     61
# NJ     60
# MN     60
# UT     58
# KS     49
# WV     46
# ID     37
# AK     36
# MA     33
# IA     31
# HI     29
# MT     29
# NE     24
# ME     21
# CT     20
# SD     14
# WY     13
# DC     13
# NH     12
# ND     11
# DE     10
# VT      8
# RI      4
# Name: state, dtype: int64

# %% [markdown]
# # Which Year has the most death rates?

# %%
The_2015_death_count = Shootings_df[Shootings_df.year == 2015]
The_2015_death_count.name.nunique() # This is the total number deaths in 2015..
# Out:
# 965

# %%
The_2015_death_count
# Out:
#        id                       name       date   manner_of_death       armed  \
# 0       3                 Tim Elliot 2015-01-02              shot         gun
# 1       4           Lewis Lee Lembke 2015-01-02              shot         gun
# 2       5         John Paul Quintero 2015-01-03  shot and Tasered     unarmed
# 3       8            Matthew Hoffman 2015-01-04              shot  toy weapon
# 4       9          Michael Rodriguez 2015-01-04              shot    nail gun
# ..    ...                        ...        ...               ...         ...
# 960  1131       Corey Jason Achstein 2015-12-28              shot  toy weapon
# 961  1133  Siolosega Velega-Nuufolau 2015-12-29              shot       knife
# 962  1134                   Tien Hua 2015-12-29              shot     unknown
# 963  1135                 Fred Perez 2015-12-30              shot       knife
# 964  1137            Keith Childress 2015-12-31              shot     unarmed
#
# ...

# %%
The_2016_death_count = Shootings_df[Shootings_df.year == 2016]
The_2016_death_count.name.nunique() # This is the total number of deaths in 2016
# Out:
# 903

# %%
The_2017_death_count = Shootings_df[Shootings_df.year == 2017]
The_2017_death_count.name.nunique() # This is the total number of deaths in 2017
# Out:
# 897

# %%
The_2018_death_count = Shootings_df[Shootings_df.year == 2018]
The_2018_death_count.name.nunique() # This is the total number of deaths in 2018
# Out:
# 880

# %%
The_2019_death_count = Shootings_df[Shootings_df.year == 2019]
The_2019_death_count.name.nunique() # This is the total number of deaths in 2019
# Out:
# 849

# %%
The_2020_death_count = Shootings_df[Shootings_df.year == 2020]
The_2020_death_count.name.nunique() # This is the total number of deaths in 2020
# Out:
# 370

# %% [markdown]
# ### It seems like 2015 has the most death rates................

# %%
Shootings_df.sort_values('age', ascending = False).tail(1)
# Out:
#         id              name       date manner_of_death    armed  age gender  \
# 2761  3229  Kameron Prescott 2017-12-21            shot  unarmed  6.0      M
#
#        race     city state  ...  threat_level         flee body_camera  \
# 2761  White  Schertz    TX  ...         other  Not fleeing       False
#
#       arms_category  year  month  day  weekday  Total_Deaths  \
# 2761        Unarmed  2017     12   21        3          4895
#
#                        Country
# 2761  United_States_Of_America
#
# [1 rows x 21 columns]

# %% [markdown]
# ## According to the Analysis, The youngest killed person is 6 Years old and a Male.

# %%
Shootings_df.age.unique()
# Out:
# array([53.       , 47.       , 23.       , 32.       , 39.       ,
#        18.       , 22.       , 35.       , 34.       , 25.       ,
#        31.       , 41.       , 30.       , 37.       , 28.       ,
#        42.       , 36.       , 49.       , 71.       , 33.       ,
#        29.       , 43.       , 24.       , 75.       , 68.       ,
#        27.       , 48.       , 21.       , 67.       , 19.       ,
#        54.       , 17.       , 56.       , 61.       , 45.       ,
#        26.       , 40.       , 59.       , 38.       , 51.       ,
#        74.       , 57.       , 46.       , 16.       , 50.       ,
#        20.       , 77.       , 37.1179309, 58.       , 64.       ,
#        52.       , 63.       , 44.       , 60.       , 66.       ,
#        83.       , 72.       , 76.       , 62.       , 55.       ,
#        69.       , 15.       , 65.       ,  6.       , 12.       ,
#        70.       , 80.       , 14.       , 82.       , 13.       ,
# ...

# %%
Shootings_df['Total_Deaths'] = Shootings_df.id.nunique()

# %%
Shootings_df.sample(8)
# Out:
#         id                   name       date manner_of_death    armed   age  \
# 3946  4694       Lawrence Bottoms 2019-04-29            shot      gun  29.0
# 3320  3878       Anthony C. Lopez 2018-07-21            shot  vehicle  21.0
# 4438  5390       Chad James Green 2019-12-05            shot      gun  41.0
# 4286  5085    Joshua Chase Conner 2019-10-07            shot    knife  31.0
# 2166  2518        Brandon Pequeno 2017-04-20            shot  unknown  25.0
# 3248  3792  Anthony Marcell Green 2018-06-20            shot  unarmed  33.0
# 1544  1777   Jeffrey Allen Morris 2016-08-09            shot  unknown  44.0
# 2774  3257     Heath Wayne Hodges 2017-12-30            shot  unknown  36.0
#
#      gender      race            city state  signs_of_mental_illness  \
# 3946      M     White  Hancock County    MS                    False
# 3320      M  Hispanic            Mesa    AZ                    False
# 4438      M     White  San Bernardino    CA                    False
# ...

# %%
import numpy as np
plt.figure(figsize = (17, 7))
plt.xlabel('Age')
plt.title('Age Distribution')

plt.hist(Shootings_df.age, bins = np.arange(10, 100, 5), color = 'purple');

# %%
Shootings_df['Country'] = 'United_States_Of_America'

# %%
Shootings_df
# Out:
#         id                name       date   manner_of_death       armed   age  \
# 0        3          Tim Elliot 2015-01-02              shot         gun  53.0
# 1        4    Lewis Lee Lembke 2015-01-02              shot         gun  47.0
# 2        5  John Paul Quintero 2015-01-03  shot and Tasered     unarmed  23.0
# 3        8     Matthew Hoffman 2015-01-04              shot  toy weapon  32.0
# 4        9   Michael Rodriguez 2015-01-04              shot    nail gun  39.0
# ...    ...                 ...        ...               ...         ...   ...
# 4890  5916     Rayshard Brooks 2020-06-12              shot       Taser  27.0
# 4891  5925      Caine Van Pelt 2020-06-12              shot         gun  23.0
# 4892  5918        Hannah Fizer 2020-06-13              shot     unarmed  25.0
# 4893  5921      William Slyter 2020-06-13              shot         gun  22.0
# 4894  5924      Nicholas Hirsh 2020-06-15              shot         gun  31.0
#
# ...

# %% [markdown]
# # Find the percentage rate of death in America?

# %%
rate_of_deaths = Shootings_df.id.nunique() / 52000000

# %%
percentage_rate_of_deaths = rate_of_deaths * 100

# %%
percentage_rate_of_deaths
# Out:
# 0.009413461538461537

# %%
print(f'The percentage Rate of death is {percentage_rate_of_deaths}' )
# Out:
# The percentage Rate of death is 0.009413461538461537

# %%
Shootings_df['Percentage_death_rate'] = '0.1%'

# %%
Shootings_df
# Out:
#         id                name       date   manner_of_death       armed   age  \
# 0        3          Tim Elliot 2015-01-02              shot         gun  53.0
# 1        4    Lewis Lee Lembke 2015-01-02              shot         gun  47.0
# 2        5  John Paul Quintero 2015-01-03  shot and Tasered     unarmed  23.0
# 3        8     Matthew Hoffman 2015-01-04              shot  toy weapon  32.0
# 4        9   Michael Rodriguez 2015-01-04              shot    nail gun  39.0
# ...    ...                 ...        ...               ...         ...   ...
# 4890  5916     Rayshard Brooks 2020-06-12              shot       Taser  27.0
# 4891  5925      Caine Van Pelt 2020-06-12              shot         gun  23.0
# 4892  5918        Hannah Fizer 2020-06-13              shot     unarmed  25.0
# 4893  5921      William Slyter 2020-06-13              shot         gun  22.0
# 4894  5924      Nicholas Hirsh 2020-06-15              shot         gun  31.0
#
# ...

# %%
Shooting_df_analysis = Shootings_df.copy

# %%
Shooting_df_analysis
# Out:
# <bound method NDFrame.copy of         id                name       date   manner_of_death       armed   age  \
# 0        3          Tim Elliot 2015-01-02              shot         gun  53.0
# 1        4    Lewis Lee Lembke 2015-01-02              shot         gun  47.0
# 2        5  John Paul Quintero 2015-01-03  shot and Tasered     unarmed  23.0
# 3        8     Matthew Hoffman 2015-01-04              shot  toy weapon  32.0
# 4        9   Michael Rodriguez 2015-01-04              shot    nail gun  39.0
# ...    ...                 ...        ...               ...         ...   ...
# 4890  5916     Rayshard Brooks 2020-06-12              shot       Taser  27.0
# 4891  5925      Caine Van Pelt 2020-06-12              shot         gun  23.0
# 4892  5918        Hannah Fizer 2020-06-13              shot     unarmed  25.0
# 4893  5921      William Slyter 2020-06-13              shot         gun  22.0
# 4894  5924      Nicholas Hirsh 2020-06-15              shot         gun  31.0
#
# ...

# %%
Shooting_df_analysis.to_csv("New_Shootings.csv", index = None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-204-06a78f52cddc> in <module>
# ----> 1 Shooting_df_analysis.to_csv("New_Shootings.csv", index = None)
#
# AttributeError: 'function' object has no attribute 'to_csv'
